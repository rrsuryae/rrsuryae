# %% [markdown]
# <a href="https://colab.research.google.com/github/rrsuryae/rrsuryae/blob/master/Rekha_NVIDIA_apex_Successful.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Mar  5 00:26:40 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 61.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !cat /usr/local/cuda/version.txt

import torch
print(torch.__version__)

if torch.__version__ > '1.2.0':
    # https://github.com/NVIDIA/apex/issues/627
    # !pip install https://download.pytorch.org/whl/cu100/torch-1.2.0-cp36-cp36m-manylinux1_x86_64.whl
    # !pip install https://download.pytorch.org/whl/cu100/torchvision-0.4.0-cp36-cp36m-manylinux1_x86_64.whl
# Out:
# cat: /usr/local/cuda/version.txt: No such file or directory
# 2.5.1+cu124
# ERROR: torch-1.2.0-cp36-cp36m-manylinux1_x86_64.whl is not a supported wheel on this platform.
# ERROR: torchvision-0.4.0-cp36-cp36m-manylinux1_x86_64.whl is not a supported wheel on this platform.

# %%
# !git clone https://github.com/NVIDIA/apex
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./apex
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 11989, done.
# remote: Total 11989 (delta 0), reused 0 (delta 0), pack-reused 11989 (from 1)
# Receiving objects: 100% (11989/11989), 15.65 MiB | 26.63 MiB/s, done.
# Resolving deltas: 100% (8348/8348), done.
# Using pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)
# DEPRECATION: --build-option and --global-option are deprecated. pip 24.2 will enforce this behaviour change. A possible replacement is to use --config-settings. Discussion can be found at https://github.com/pypa/pip/issues/11859
# WARNING: Implying --no-binary=:all: due to the presence of --build-option / --global-option.
# Processing ./apex
#   Running command pip subprocess to install build dependencies
#   Using pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)
#   Non-user install by explicit request
#   Created build tracker: /tmp/pip-build-tracker-n724x6ry
# ...

# %%
# !pip3 install --pre torch torchvision torchaudio --index-url https://download.pytorch.org/whl/nightly/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu118
# ...

# %%
# !pip install git+https://github.com/pytorch/vision.git
# Out:
# ...
#   Cloning https://github.com/pytorch/vision.git to /tmp/pip-req-build-0mnzvdkl
#   Running command git clone --filter=blob:none --quiet https://github.com/pytorch/vision.git /tmp/pip-req-build-0mnzvdkl
#   Resolved https://github.com/pytorch/vision.git to commit 124dfa404f395db90280e6dd84a51c50c742d5fd
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for torchvision: filename=torchvision-0.22.0a0+124dfa4-cp311-cp311-linux_x86_64.whl size=5443284 sha256=a42394b7e098bca625aef8617831c787984455ef5ca5de7eeec9359dd03284b8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mz0vqcls/wheels/eb/ca/fe/99355e078d25b4fc5bd9da6a6ee6a176f09f47a50372c74951
# Successfully built torchvision
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu124
#     Uninstalling torchvision-0.20.1+cu124:
#       Successfully uninstalled torchvision-0.20.1+cu124
# ...

# %%
# !pip install pycocotools

# %%
# !pip install yacs

# %%
# !pip install matplotlib

# %%
# !pip install opencv-python

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !nvidia-smi
# Out:
# Wed Mar  5 02:01:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip3 install --pre torch torchvision torchaudio --index-url https://download.pytorch.org/whl/nightly/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu126
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/NVIDIA/apex.git
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 11989, done.
# remote: Total 11989 (delta 0), reused 0 (delta 0), pack-reused 11989 (from 1)
# Receiving objects: 100% (11989/11989), 15.65 MiB | 26.72 MiB/s, done.
# Resolving deltas: 100% (8348/8348), done.

# %%
# %cd apex
# Out:
# /content/apex

# %%
# !python setup.py install --cuda_ext --cpp_ext
# Out:
# torch.__version__  = 2.5.1+cu124
#
#
#
# Compiling cuda extensions with
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# from /usr/local/cuda/bin
#
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# ...

# %%
import torch
from apex import amp

print(torch.cuda.get_device_name())
# Out:
# Tesla T4

# %%
pip install ninja yacs cython matplotlib tqdm opencv-python
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/apex-0.1-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 7.9 MB/s eta 0:00:00
# ...

# %%
# !pip install tqdm
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/apex-0.1-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975 (from 1)
# Receiving objects: 100% (975/975), 11.72 MiB | 30.86 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
# %cd cocoapi/PythonAPI
# Out:
# /content/cocoapi/PythonAPI

# %%
# !python setup.py build_ext install
# Out:
# running build_ext
# Compiling pycocotools/_mask.pyx because it changed.
# [1/1] Cythonizing pycocotools/_mask.pyx
# /usr/local/lib/python3.11/dist-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /content/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build/temp.linux-x86_64-cpython-311/../common
# creating build/temp.linux-x86_64-cpython-311/pycocotools
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I../common -I/usr/include/python3.11 -c ../common/maskApi.c -o build/temp.linux-x86_64-cpython-311/../common/maskApi.o -Wno-cpp -Wno-unused-function -std=c99
# ../common/maskApi.c: In function ‘rleDecode’:
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/mcordts/cityscapesScripts.git
# Out:
# Cloning into 'cityscapesScripts'...
# remote: Enumerating objects: 671, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 671 (delta 193), reused 181 (delta 161), pack-reused 427 (from 1)
# Receiving objects: 100% (671/671), 836.47 KiB | 15.78 MiB/s, done.
# Resolving deltas: 100% (379/379), done.

# %%
# %cd cityscapesScripts/
# Out:
# /content/cityscapesScripts

# %%
# !python setup.py build_ext install
# Out:
# /usr/local/lib/python3.11/dist-packages/setuptools/dist.py:452: SetuptoolsDeprecationWarning: Invalid dash-separated options
# !!
#
#         ********************************************************************************
#         Usage of dash-separated 'description-file' will not be supported in future
#         versions. Please use the underscore name 'description_file' instead.
#
#         This deprecation is overdue, please update your project and remove deprecated
#         calls to avoid build errors in the future.
#
#         See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#         ********************************************************************************
#
# !!
#   opt = self.warn_dash_deprecation(opt, section)
# /usr/local/lib/python3.11/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/facebookresearch/maskrcnn-benchmark.git
# Out:
# Cloning into 'maskrcnn-benchmark'...
# remote: Enumerating objects: 1932, done.
# remote: Total 1932 (delta 0), reused 0 (delta 0), pack-reused 1932 (from 1)
# Receiving objects: 100% (1932/1932), 6.67 MiB | 30.35 MiB/s, done.
# Resolving deltas: 100% (1203/1203), done.

# %%
# %cd maskrcnn-benchmark
# Out:
# /content/maskrcnn-benchmark

# %%
# !python setup.py build develop
# Out:
# running build
# running build_py
# creating build/lib.linux-x86_64-cpython-311/maskrcnn_benchmark
# copying maskrcnn_benchmark/__init__.py -> build/lib.linux-x86_64-cpython-311/maskrcnn_benchmark
# creating build/lib.linux-x86_64-cpython-311/maskrcnn_benchmark/data
# copying maskrcnn_benchmark/data/__init__.py -> build/lib.linux-x86_64-cpython-311/maskrcnn_benchmark/data
# copying maskrcnn_benchmark/data/collate_batch.py -> build/lib.linux-x86_64-cpython-311/maskrcnn_benchmark/data
# copying maskrcnn_benchmark/data/build.py -> build/lib.linux-x86_64-cpython-311/maskrcnn_benchmark/data
# creating build/lib.linux-x86_64-cpython-311/maskrcnn_benchmark/utils
# copying maskrcnn_benchmark/utils/__init__.py -> build/lib.linux-x86_64-cpython-311/maskrcnn_benchmark/utils
# copying maskrcnn_benchmark/utils/cv2_util.py -> build/lib.linux-x86_64-cpython-311/maskrcnn_benchmark/utils
# copying maskrcnn_benchmark/utils/checkpoint.py -> build/lib.linux-x86_64-cpython-311/maskrcnn_benchmark/utils
# ...
