# %% [markdown]
# <a href="https://colab.research.google.com/github/rrsuryae/rrsuryae/blob/master/detectron2_bdd100k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/egirgin/detectron2-bdd100k.git
# Out:
# Cloning into 'detectron2-bdd100k'...
# remote: Enumerating objects: 13423, done.
# remote: Counting objects: 100% (1765/1765), done.
# remote: Compressing objects: 100% (1569/1569), done.
# remote: Total 13423 (delta 194), reused 1761 (delta 191), pack-reused 11658 (from 1)
# Receiving objects: 100% (13423/13423), 385.72 MiB | 57.53 MiB/s, done.
# Resolving deltas: 100% (863/863), done.
# Updating files: 100% (12017/12017), done.

# %%
# %cd detectron2-bdd100k
# Out:
# /content/detectron2-bdd100k

# %%
# Install PyTorch
# !pip install torch torchvision torchaudio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# Install Detectron2
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-89j85bxk
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-89j85bxk
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 9604f5995cc628619f0e4fd913453b4d7d61db3f
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.0 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/facebookresearch/detectron2.git
# Out:
# Cloning into 'detectron2'...
# remote: Enumerating objects: 15837, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 15837 (delta 35), reused 14 (delta 14), pack-reused 15772 (from 2)
# Receiving objects: 100% (15837/15837), 6.41 MiB | 22.48 MiB/s, done.
# Resolving deltas: 100% (11533/11533), done.

# %%
# %cd detectron2
# Out:
# /content/detectron2

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/detectron2
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: detectron2
#     Found existing installation: detectron2 0.6
#     Uninstalling detectron2-0.6:
#       Successfully uninstalled detectron2-0.6
#   Running setup.py develop for detectron2
# ...

# %%
# %cd /content/detectron2-bdd100k
# Out:
# /content/detectron2-bdd100k

# %%
import torch
import detectron2
print("Torch version:", torch.__version__)
print("Detectron2 version:", detectron2.__version__)
# Out:
# Torch version: 2.6.0+cu124
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-11b583da1b7f> in <cell line: 0>()
#       2 import detectron2
#       3 print("Torch version:", torch.__version__)
# ----> 4 print("Detectron2 version:", detectron2.__version__)
#
# AttributeError: module 'detectron2' has no attribute '__version__'

# %%
# !ls data/
# Out:
# ls: cannot access 'data/': No such file or directory

# %%
# !mkdir -p data
# %cd data
# Out:
# /content/detectron2-bdd100k/data

# %%
# !wget https://bdd-data.berkeley.edu/bdd100k_images.zip
# !wget https://bdd-data.berkeley.edu/bdd100k_labels.zip
# Out:
# --2025-03-16 18:34:10--  https://bdd-data.berkeley.edu/bdd100k_images.zip
# Resolving bdd-data.berkeley.edu (bdd-data.berkeley.edu)... 128.32.162.150
# Connecting to bdd-data.berkeley.edu (bdd-data.berkeley.edu)|128.32.162.150|:443... failed: Connection timed out.
# Retrying.
#
# --2025-03-16 18:36:23--  (try: 2)  https://bdd-data.berkeley.edu/bdd100k_images.zip
# Connecting to bdd-data.berkeley.edu (bdd-data.berkeley.edu)|128.32.162.150|:443... failed: Connection timed out.
# Retrying.
#
# --2025-03-16 18:38:35--  (try: 3)  https://bdd-data.berkeley.edu/bdd100k_images.zip
# Connecting to bdd-data.berkeley.edu (bdd-data.berkeley.edu)|128.32.162.150|:443... failed: Connection timed out.
# Retrying.
#
# --2025-03-16 18:40:48--  (try: 4)  https://bdd-data.berkeley.edu/bdd100k_images.zip
# Connecting to bdd-data.berkeley.edu (bdd-data.berkeley.edu)|128.32.162.150|:443... failed: Connection timed out.
# Retrying.
#
# ...

# %%
# Unzip datasets
# !unzip -q bdd100k_images.zip
# !unzip -q bdd100k_labels.zip
# %cd ..

# %%
# %cd /content/detectron2-bdd100k
# Out:
# /content/detectron2-bdd100k

# %%
# !python train.py --trainer "custom" --bitmap_path "/content/detectron2-bdd100k/subdataset/bitmaps" --images_path "/content/detectron2-bdd100k/subdataset/imgs" \
                  --epochs 10 --batch_size 4 --eval_period 2 --checkpoint_period 1 --name "bdd100k"
# Out:
# Creating trainset...
# Creating valset...
# cfg.SOLVER.MAX_ITER: 300
# 5000it [02:39, 31.42it/s]
# [03/16 22:24:21 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# | main_path  | 4590         |   error    | 0            |  alt_path  | 4261         |
# |            |              |            |              |            |              |
# |   total    | 8851         |            |              |            |              |
# 1000it [00:31, 31.59it/s]
# [03/16 22:24:53 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# | main_path  | 920          |   error    | 0            |  alt_path  | 858          |
# ...

# %%
# !python test.py --weights "/content/detectron2-bdd100k/output/bdd100k/checkpoint/last_checkpoint" --output "/content/detectron2-bdd100k/output/bdd100k/results" --images "/content/detectron2-bdd100k/subdataset/imgs/val"
